# %% [markdown]
# ## Import Package

# %%
import pandas as pd
import numpy as np
import datetime as dt
from operator import attrgetter
from scipy import stats
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:151: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Import Csv

# %%
df = pd.read_csv("/content/drive/MyDrive/online_retail_II.csv", header = 0)
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                      ...    ...          ...             ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France
#
# [1067371 rows x 8 columns]

# %% [markdown]
# ## DataCleaning

# %%
df_resik = df.copy()

# create date columns
df_resik['InvoiceDate'] = df_resik['InvoiceDate'].astype('datetime64[ns]')

# convert datetime
df_resik['InvoiceDate'] = pd.to_datetime(df_resik['InvoiceDate'], errors='coerce')

# Create month column
df_resik['year_month'] = df_resik['InvoiceDate'].dt.to_period('M')

# Remove all customer id
df_resik = df_resik[~df_resik['Customer ID'].isna()]

# Remove all description
df_resik = df_resik[~df_resik['Description'].isna()]

# Make all item in description column with no capital
df_resik['Description'] = df_resik['Description'].str.lower()

# Remove all name in the row, that name p, w and post or special characters
df_resik = df_resik[~df_resik['StockCode'].str.match('^\d+$', case=False, na=False)]

# Adding order statu
df_resik['order_status'] = np.where(df_resik['Invoice'].str[:1] == 'C', ' Cancelled', 'Delivereed')

# change negatif to positif in quantity
df_resik['Quantity'] = df_resik['Quantity'].abs()

# Remove all negative quantity
df_resik = df_resik[df_resik['Quantity'] > 0 ]

# Create new column by name amount
df_resik['Amount'] = df_resik['Quantity'] * df_resik['Price']

# Get the most common in description for every stockcode
most_freq_product_name = df_resik.groupby(['StockCode', 'Description'], as_index=False) \
  .agg(order_cnt=('Invoice', 'nunique')).sort_values(['StockCode', 'order_cnt'], ascending=[True, False])
most_freq_product_name['rank'] = most_freq_product_name.groupby('StockCode')['order_cnt'].rank(method='first', ascending=False)
most_freq_product_name = most_freq_product_name[most_freq_product_name['rank'] == 1].drop(columns=['order_cnt', 'rank'])

df_resik = df_resik.merge(
    most_freq_product_name.rename(columns={'Description' : 'most_freq_product_name'}),
    on='StockCode',
    how='left'
)

df_resik['Description'] = df_resik['most_freq_product_name']
df_resik = df_resik.drop(columns=['most_freq_product_name'])

# change customer ID to String
df_resik['Customer ID'] = df_resik['Customer ID'].astype(str)

# outlier remove
df_resik = df_resik[(np.abs(stats.zscore(df_resik[['Quantity', 'Amount']])) < 3).all(axis=1)]
df_resik = df_resik.reset_index(drop=True)
df_resik
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\d'
# <>:22: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3871403617.py:22: SyntaxWarning: invalid escape sequence '\d'
#   df_resik = df_resik[~df_resik['StockCode'].str.match('^\d+$', case=False, na=False)]
#       Invoice StockCode                     Description  Quantity  \
# 0      489434    79323P              pink cherry lights        12
# 1      489434    79323W             white cherry lights        12
# 2      489436    48173C            doormat black flock         10
# 3      489436    35004B     set of 3 black flying ducks        12
# 4      489436    84596F    small marshmallows pink bowl         8
# ...       ...       ...                             ...       ...
# 93933  581579    85099C  jumbo  bag baroque black white        10
# 93934  581580    84993A       75 green petit four cases         2
# 93935  581580    85049A   traditional christmas ribbons         1
# 93936  581580    85049E       scandinavian reds ribbons         2
# 93937  581587      POST                         postage         1
#
#               InvoiceDate  Price Customer ID         Country year_month  \
# 0     2009-12-01 07:45:00   6.75     13085.0  United Kingdom    2009-12
# 1     2009-12-01 07:45:00   6.75     13085.0  United Kingdom    2009-12
# 2     2009-12-01 09:06:00   5.95     13078.0  United Kingdom    2009-12
# 3     2009-12-01 09:06:00   4.65     13078.0  United Kingdom    2009-12
# 4     2009-12-01 09:06:00   1.25     13078.0  United Kingdom    2009-12
# ...                   ...    ...         ...             ...        ...
# 93933 2011-12-09 12:19:00   1.79     17581.0  United Kingdom    2011-12
# 93934 2011-12-09 12:20:00   0.42     12748.0  United Kingdom    2011-12
# 93935 2011-12-09 12:20:00   1.25     12748.0  United Kingdom    2011-12
# 93936 2011-12-09 12:20:00   1.25     12748.0  United Kingdom    2011-12
# 93937 2011-12-09 12:50:00  18.00     12680.0          France    2011-12
#
#       order_status  Amount
# 0       Delivereed   81.00
# 1       Delivereed   81.00
# 2       Delivereed   59.50
# 3       Delivereed   55.80
# 4       Delivereed   10.00
# ...            ...     ...
# 93933   Delivereed   17.90
# 93934   Delivereed    0.84
# 93935   Delivereed    1.25
# 93936   Delivereed    2.50
# 93937   Delivereed   18.00
#
# [93938 rows x 11 columns]

# %%
df_resik.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93938 entries, 0 to 93937
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Invoice       93938 non-null  object
#  1   StockCode     93938 non-null  object
#  2   Description   93938 non-null  object
#  3   Quantity      93938 non-null  int64
#  4   InvoiceDate   93938 non-null  datetime64[ns]
#  5   Price         93938 non-null  float64
#  6   Customer ID   93938 non-null  object
#  7   Country       93938 non-null  object
#  8   year_month    93938 non-null  period[M]
#  9   order_status  93938 non-null  object
#  10  Amount        93938 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6), period[M](1)
# memory usage: 7.9+ MB

# %% [markdown]
# ## Already online retail

# %% [markdown]
# Create online retail dataframe

# %%
london = pd.pivot_table(df_resik, index='Invoice', columns='Description', values='StockCode', aggfunc='nunique', fill_value=0)
london
# Out:
# Description   4 purple flock dinner candles   silver cherry lights  \
# Invoice
# 489434                                    0                      0
# 489436                                    0                      0
# 489437                                    0                      0
# 489438                                    0                      0
# 489439                                    0                      0
# ...                                     ...                    ...
# C581228                                   0                      0
# C581229                                   0                      0
# C581330                                   0                      0
# C581409                                   0                      0
# C581499                                   0                      0
#
# Description   white cherry lights  3 black cats w hearts blank card  \
# Invoice
# 489434                          1                                 0
# 489436                          0                                 0
# 489437                          0                                 0
# 489438                          0                                 0
# 489439                          0                                 0
# ...                           ...                               ...
# C581228                         0                                 0
# C581229                         0                                 0
# C581330                         0                                 0
# C581409                         0                                 0
# C581499                         0                                 0
#
# Description  3 gardenia morris boxed candles  3 rose morris boxed candles  \
# Invoice
# 489434                                     0                            0
# 489436                                     0                            0
# 489437                                     0                            0
# 489438                                     0                            0
# 489439                                     0                            0
# ...                                      ...                          ...
# C581228                                    0                            0
# C581229                                    0                            0
# C581330                                    0                            0
# C581409                                    0                            0
# C581499                                    0                            0
#
# Description  3 white choc morris boxed candles  3d dog picture playing cards  \
# Invoice
# 489434                                       0                             0
# 489436                                       0                             0
# 489437                                       0                             0
# 489438                                       0                             0
# 489439                                       0                             0
# ...                                        ...                           ...
# C581228                                      0                             0
# C581229                                      0                             0
# C581330                                      0                             0
# C581409                                      0                             0
# C581499                                      0                             0
#
# Description  3d sheet of cat stickers  3d sheet of dog stickers  ...  \
# Invoice                                                          ...
# 489434                              0                         0  ...
# 489436                              0                         0  ...
# 489437                              0                         0  ...
# 489438                              0                         0  ...
# 489439                              0                         0  ...
# ...                               ...                       ...  ...
# C581228                             0                         0  ...
# C581229                             0                         0  ...
# C581330                             0                         0  ...
# C581409                             0                         0  ...
# C581499                             0                         0  ...
#
# Description  yellow purple daisy felt purse kit  yellow red flower piggy bank  \
# Invoice
# 489434                                        0                             0
# 489436                                        0                             0
# 489437                                        0                             0
# 489438                                        0                             0
# 489439                                        0                             0
# ...                                         ...                           ...
# C581228                                       0                             0
# C581229                                       0                             0
# C581330                                       0                             0
# C581409                                       0                             0
# C581499                                       0                             0
#
# Description  yellow shark helicopter  yellow vw beetle ceramic money box  \
# Invoice
# 489434                             0                                   0
# 489436                             0                                   0
# 489437                             0                                   0
# 489438                             0                                   0
# 489439                             0                                   0
# ...                              ...                                 ...
# C581228                            0                                   0
# C581229                            0                                   0
# C581330                            0                                   0
# C581409                            0                                   0
# C581499                            0                                   0
#
# Description  yellow/blue retro radio  yellow/orange flower design plate  \
# Invoice
# 489434                             0                                  0
# 489436                             0                                  0
# 489437                             0                                  0
# 489438                             0                                  0
# 489439                             0                                  0
# ...                              ...                                ...
# C581228                            0                                  0
# C581229                            0                                  0
# C581330                            0                                  0
# C581409                            0                                  0
# C581499                            0                                  0
#
# Description  yellow/pink ceramic candle holder  \
# Invoice
# 489434                                       0
# 489436                                       0
# 489437                                       0
# 489438                                       0
# 489439                                       0
# ...                                        ...
# C581228                                      0
# C581229                                      0
# C581330                                      0
# C581409                                      0
# C581499                                      0
#
# Description  yellow/pink flower design big mug  yuletide images gift wrap set  \
# Invoice
# 489434                                       0                              0
# 489436                                       0                              0
# 489437                                       0                              0
# 489438                                       0                              0
# 489439                                       0                              0
# ...                                        ...                            ...
# C581228                                      0                              0
# C581229                                      0                              0
# C581330                                      0                              0
# C581409                                      0                              0
# C581499                                      0                              0
#
# Description  yuletide images s/6 paper boxes
# Invoice
# 489434                                     0
# 489436                                     0
# 489437                                     0
# 489438                                     0
# 489439                                     0
# ...                                      ...
# C581228                                    0
# C581229                                    0
# C581330                                    0
# C581409                                    0
# C581499                                    0
#
# [26005 rows x 1300 columns]

# %%
london.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26005 entries, 489434 to C581499
# Columns: 1300 entries,  4 purple flock dinner candles to yuletide images s/6 paper boxes
# dtypes: int64(1300)
# memory usage: 258.1+ MB

# %% [markdown]
# ## Encode the basket DataFrame with True for all values ​​above 0 and False for all values ​​0

# %%
def encode(x):
  if x==0 :
    return False
  if x>0 :
    return True

london_encode = london.applymap(encode)
london_encode
# Out:
# /tmp/ipython-input-153822934.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   london_encode = london.applymap(encode)
# Description   4 purple flock dinner candles   silver cherry lights  \
# Invoice
# 489434                                False                  False
# 489436                                False                  False
# 489437                                False                  False
# 489438                                False                  False
# 489439                                False                  False
# ...                                     ...                    ...
# C581228                               False                  False
# C581229                               False                  False
# C581330                               False                  False
# C581409                               False                  False
# C581499                               False                  False
#
# Description   white cherry lights  3 black cats w hearts blank card  \
# Invoice
# 489434                       True                             False
# 489436                      False                             False
# 489437                      False                             False
# 489438                      False                             False
# 489439                      False                             False
# ...                           ...                               ...
# C581228                     False                             False
# C581229                     False                             False
# C581330                     False                             False
# C581409                     False                             False
# C581499                     False                             False
#
# Description  3 gardenia morris boxed candles  3 rose morris boxed candles  \
# Invoice
# 489434                                 False                        False
# 489436                                 False                        False
# 489437                                 False                        False
# 489438                                 False                        False
# 489439                                 False                        False
# ...                                      ...                          ...
# C581228                                False                        False
# C581229                                False                        False
# C581330                                False                        False
# C581409                                False                        False
# C581499                                False                        False
#
# Description  3 white choc morris boxed candles  3d dog picture playing cards  \
# Invoice
# 489434                                   False                         False
# 489436                                   False                         False
# 489437                                   False                         False
# 489438                                   False                         False
# 489439                                   False                         False
# ...                                        ...                           ...
# C581228                                  False                         False
# C581229                                  False                         False
# C581330                                  False                         False
# C581409                                  False                         False
# C581499                                  False                         False
#
# Description  3d sheet of cat stickers  3d sheet of dog stickers  ...  \
# Invoice                                                          ...
# 489434                          False                     False  ...
# 489436                          False                     False  ...
# 489437                          False                     False  ...
# 489438                          False                     False  ...
# 489439                          False                     False  ...
# ...                               ...                       ...  ...
# C581228                         False                     False  ...
# C581229                         False                     False  ...
# C581330                         False                     False  ...
# C581409                         False                     False  ...
# C581499                         False                     False  ...
#
# Description  yellow purple daisy felt purse kit  yellow red flower piggy bank  \
# Invoice
# 489434                                    False                         False
# 489436                                    False                         False
# 489437                                    False                         False
# 489438                                    False                         False
# 489439                                    False                         False
# ...                                         ...                           ...
# C581228                                   False                         False
# C581229                                   False                         False
# C581330                                   False                         False
# C581409                                   False                         False
# C581499                                   False                         False
#
# Description  yellow shark helicopter  yellow vw beetle ceramic money box  \
# Invoice
# 489434                         False                               False
# 489436                         False                               False
# 489437                         False                               False
# 489438                         False                               False
# 489439                         False                               False
# ...                              ...                                 ...
# C581228                        False                               False
# C581229                        False                               False
# C581330                        False                               False
# C581409                        False                               False
# C581499                        False                               False
#
# Description  yellow/blue retro radio  yellow/orange flower design plate  \
# Invoice
# 489434                         False                              False
# 489436                         False                              False
# 489437                         False                              False
# 489438                         False                              False
# 489439                         False                              False
# ...                              ...                                ...
# C581228                        False                              False
# C581229                        False                              False
# C581330                        False                              False
# C581409                        False                              False
# C581499                        False                              False
#
# Description  yellow/pink ceramic candle holder  \
# Invoice
# 489434                                   False
# 489436                                   False
# 489437                                   False
# 489438                                   False
# 489439                                   False
# ...                                        ...
# C581228                                  False
# C581229                                  False
# C581330                                  False
# C581409                                  False
# C581499                                  False
#
# Description  yellow/pink flower design big mug  yuletide images gift wrap set  \
# Invoice
# 489434                                   False                          False
# 489436                                   False                          False
# 489437                                   False                          False
# 489438                                   False                          False
# 489439                                   False                          False
# ...                                        ...                            ...
# C581228                                  False                          False
# C581229                                  False                          False
# C581330                                  False                          False
# C581409                                  False                          False
# C581499                                  False                          False
#
# Description  yuletide images s/6 paper boxes
# Invoice
# 489434                                 False
# 489436                                 False
# 489437                                 False
# 489438                                 False
# 489439                                 False
# ...                                      ...
# C581228                                False
# C581229                                False
# C581330                                False
# C581409                                False
# C581499                                False
#
# [26005 rows x 1300 columns]

# %%
london_encode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26005 entries, 489434 to C581499
# Columns: 1300 entries,  4 purple flock dinner candles to yuletide images s/6 paper boxes
# dtypes: bool(1300)
# memory usage: 32.4+ MB

# %% [markdown]
# ## Take transactions with more than 1 unique product

# %%
london_filter = london_encode[(london_encode>0).sum(axis=1)>1]
london_filter
# Out:
# Description   4 purple flock dinner candles   silver cherry lights  \
# Invoice
# 489434                                False                  False
# 489436                                False                  False
# 489437                                False                  False
# 489438                                False                  False
# 489439                                False                  False
# ...                                     ...                    ...
# C579926                               False                  False
# C579929                               False                  False
# C580954                               False                  False
# C580971                               False                  False
# C581229                               False                  False
#
# Description   white cherry lights  3 black cats w hearts blank card  \
# Invoice
# 489434                       True                             False
# 489436                      False                             False
# 489437                      False                             False
# 489438                      False                             False
# 489439                      False                             False
# ...                           ...                               ...
# C579926                     False                             False
# C579929                     False                             False
# C580954                     False                             False
# C580971                     False                             False
# C581229                     False                             False
#
# Description  3 gardenia morris boxed candles  3 rose morris boxed candles  \
# Invoice
# 489434                                 False                        False
# 489436                                 False                        False
# 489437                                 False                        False
# 489438                                 False                        False
# 489439                                 False                        False
# ...                                      ...                          ...
# C579926                                False                        False
# C579929                                False                         True
# C580954                                False                        False
# C580971                                False                        False
# C581229                                False                        False
#
# Description  3 white choc morris boxed candles  3d dog picture playing cards  \
# Invoice
# 489434                                   False                         False
# 489436                                   False                         False
# 489437                                   False                         False
# 489438                                   False                         False
# 489439                                   False                         False
# ...                                        ...                           ...
# C579926                                  False                         False
# C579929                                  False                         False
# C580954                                  False                         False
# C580971                                  False                         False
# C581229                                  False                         False
#
# Description  3d sheet of cat stickers  3d sheet of dog stickers  ...  \
# Invoice                                                          ...
# 489434                          False                     False  ...
# 489436                          False                     False  ...
# 489437                          False                     False  ...
# 489438                          False                     False  ...
# 489439                          False                     False  ...
# ...                               ...                       ...  ...
# C579926                         False                     False  ...
# C579929                         False                     False  ...
# C580954                         False                     False  ...
# C580971                         False                     False  ...
# C581229                         False                     False  ...
#
# Description  yellow purple daisy felt purse kit  yellow red flower piggy bank  \
# Invoice
# 489434                                    False                         False
# 489436                                    False                         False
# 489437                                    False                         False
# 489438                                    False                         False
# 489439                                    False                         False
# ...                                         ...                           ...
# C579926                                   False                         False
# C579929                                   False                         False
# C580954                                   False                         False
# C580971                                   False                         False
# C581229                                   False                         False
#
# Description  yellow shark helicopter  yellow vw beetle ceramic money box  \
# Invoice
# 489434                         False                               False
# 489436                         False                               False
# 489437                         False                               False
# 489438                         False                               False
# 489439                         False                               False
# ...                              ...                                 ...
# C579926                        False                               False
# C579929                        False                               False
# C580954                        False                               False
# C580971                        False                               False
# C581229                        False                               False
#
# Description  yellow/blue retro radio  yellow/orange flower design plate  \
# Invoice
# 489434                         False                              False
# 489436                         False                              False
# 489437                         False                              False
# 489438                         False                              False
# 489439                         False                              False
# ...                              ...                                ...
# C579926                        False                              False
# C579929                        False                              False
# C580954                        False                              False
# C580971                        False                              False
# C581229                        False                              False
#
# Description  yellow/pink ceramic candle holder  \
# Invoice
# 489434                                   False
# 489436                                   False
# 489437                                   False
# 489438                                   False
# 489439                                   False
# ...                                        ...
# C579926                                  False
# C579929                                  False
# C580954                                  False
# C580971                                  False
# C581229                                  False
#
# Description  yellow/pink flower design big mug  yuletide images gift wrap set  \
# Invoice
# 489434                                   False                          False
# 489436                                   False                          False
# 489437                                   False                          False
# 489438                                   False                          False
# 489439                                   False                          False
# ...                                        ...                            ...
# C579926                                  False                          False
# C579929                                  False                          False
# C580954                                  False                          False
# C580971                                  False                          False
# C581229                                  False                          False
#
# Description  yuletide images s/6 paper boxes
# Invoice
# 489434                                 False
# 489436                                 False
# 489437                                 False
# 489438                                 False
# 489439                                 False
# ...                                      ...
# C579926                                False
# C579929                                False
# C580954                                False
# C580971                                False
# C581229                                False
#
# [16581 rows x 1300 columns]

# %%
london_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16581 entries, 489434 to C581229
# Columns: 1300 entries,  4 purple flock dinner candles to yuletide images s/6 paper boxes
# dtypes: bool(1300)
# memory usage: 20.7+ MB

# %% [markdown]
# ## Applying a priori algorithm

# %% [markdown]
# Create a frequent itemset list (a collection of products that are frequently purchased)

# %%
frequent_itemsets = apriori(london_filter, min_support=.01, use_colnames=True) \
  .sort_values('support', ascending=False).reset_index(drop=True)

frequent_itemsets['product_cnt'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#       support                                           itemsets  product_cnt
# 0    0.230083               (white hanging heart t-light holder)            1
# 1    0.162837                          (jumbo bag red retrospot)            1
# 2    0.091551                      (wooden frame antique white )            1
# 3    0.084494                             (jumbo bag strawberry)            1
# 4    0.079850                   (jumbo  bag baroque black white)            1
# ..        ...                                                ...          ...
# 154  0.010192                (rose scent candle in jewelled box)            1
# 155  0.010132                           (feather pen,coal black)            1
# 156  0.010132  (black/blue polkadot umbrella, edwardian paras...            2
# 157  0.010132  (white hanging heart t-light holder, tea time ...            2
# 158  0.010011  (white hanging heart t-light holder, red 3 pie...            2
#
# [159 rows x 3 columns]

# %% [markdown]
# ## Calculate the support, confidence, and lift values ​​of each possible product pair

# %%
assosiation_product = assosiation_product = association_rules(
    frequent_itemsets,
    metric='confidence',
    min_threshold=0.7
).sort_values(['support', 'confidence'], ascending=[False, False]).reset_index(drop=True)
assosiation_product
# Out:
#                                           antecedents  \
# 0                (blue 3 piece mini dots cutlery set)
# 1                       (blue happy birthday bunting)
# 2               (green 3 piece mini dots cutlery set)
# 3               (green 3 piece mini dots cutlery set)
# 4   (red 3 piece mini dots cutlery set, pink 3 pie...
# 5   (red 3 piece mini dots cutlery set, blue 3 pie...
# 6   (jumbo bag strawberry, jumbo  bag baroque blac...
# 7                      (small marshmallows pink bowl)
# 8   (green 3 piece mini dots cutlery set, blue 3 p...
# 9   (pink 3 piece mini dots cutlery set, green 3 p...
# 10  (pink 3 piece mini dots cutlery set, green 3 p...
# 11  (red 3 piece mini dots cutlery set, green 3 pi...
# 12  (green 3 piece mini dots cutlery set, blue 3 p...
# 13  (red 3 piece mini dots cutlery set, green 3 pi...
# 14               (set/6 turquoise butterfly t-lights)
# 15  (red 3 piece mini dots cutlery set, green 3 pi...
# 16  (red 3 piece mini dots cutlery set, pink 3 pie...
# 17  (pink 3 piece mini dots cutlery set, green 3 p...
# 18  (green 3 piece mini dots cutlery set, blue 3 p...
# 19                           (edwardian parasol pink)
# 20                               (pink cherry lights)
# 21                                 (blue party bags )
# 22                       (small chocolates pink bowl)
#
#                                           consequents  antecedent support  \
# 0                (pink 3 piece mini dots cutlery set)            0.052349
# 1                       (pink happy birthday bunting)            0.035402
# 2                 (red 3 piece mini dots cutlery set)            0.032326
# 3                (pink 3 piece mini dots cutlery set)            0.032326
# 4                (blue 3 piece mini dots cutlery set)            0.030758
# 5                (pink 3 piece mini dots cutlery set)            0.032507
# 6                           (jumbo bag red retrospot)            0.030155
# 7                (small dolly mix design orange bowl)            0.024305
# 8                (pink 3 piece mini dots cutlery set)            0.020505
# 9                 (red 3 piece mini dots cutlery set)            0.022978
# 10               (blue 3 piece mini dots cutlery set)            0.022978
# 11               (pink 3 piece mini dots cutlery set)            0.023702
# 12                (red 3 piece mini dots cutlery set)            0.020505
# 13               (blue 3 piece mini dots cutlery set)            0.023702
# 14                   (set/6 pink  butterfly t-lights)            0.020928
# 15               (pink 3 piece mini dots cutlery set)            0.016947
# 16               (blue 3 piece mini dots cutlery set)            0.017731
# 17                (red 3 piece mini dots cutlery set)            0.017731
# 18  (red 3 piece mini dots cutlery set, pink 3 pie...            0.020505
# 19                        (edwardian parasol natural)            0.019118
# 20                             ( white cherry lights)            0.017611
# 21                                  (pink party bags)            0.015077
# 22               (small dolly mix design orange bowl)            0.013329
#
#     consequent support   support  confidence       lift  representativity  \
# 0             0.058380  0.037030    0.707373  12.116690               1.0
# 1             0.045293  0.026476    0.747871  16.511906               1.0
# 2             0.054158  0.023702    0.733209  13.538238               1.0
# 3             0.058380  0.022978    0.710821  12.175745               1.0
# 4             0.052349  0.022857    0.743137  14.195805               1.0
# 5             0.058380  0.022857    0.703154  12.044418               1.0
# 6             0.162837  0.022194    0.736000   4.519858               1.0
# 7             0.029974  0.018334    0.754342  25.166503               1.0
# 8             0.058380  0.017731    0.864706  14.811661               1.0
# 9             0.054158  0.017731    0.771654  14.248093               1.0
# 10            0.052349  0.017731    0.771654  14.740538               1.0
# 11            0.058380  0.017731    0.748092  12.814160               1.0
# 12            0.054158  0.016947    0.826471  15.260255               1.0
# 13            0.052349  0.016947    0.715013  13.658555               1.0
# 14            0.024426  0.015258    0.729107  29.850165               1.0
# 15            0.058380  0.014716    0.868327  14.873695               1.0
# 16            0.052349  0.014716    0.829932  15.853804               1.0
# 17            0.054158  0.014716    0.829932  15.324167               1.0
# 18            0.030758  0.014716    0.717647  23.331972               1.0
# 19            0.047404  0.013389    0.700315  14.773449               1.0
# 20            0.022737  0.012544    0.712329  31.329239               1.0
# 21            0.018093  0.011218    0.744000  41.120880               1.0
# 22            0.029974  0.010313    0.773756  25.814170               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.033974    3.217819       0.968151  0.502455   0.689231    0.670835
# 1   0.024873    3.786575       0.973916  0.488320   0.735909    0.666212
# 2   0.021951    3.545253       0.957074  0.377522   0.717933    0.585424
# 3   0.021091    3.256182       0.948532  0.339270   0.692892    0.552208
# 4   0.021247    3.689328       0.959055  0.379379   0.728948    0.589887
# 5   0.020960    3.172082       0.947784  0.335993   0.684750    0.547341
# 6   0.017284    3.171072       0.802968  0.129944   0.684649    0.436148
# 7   0.017606    3.948691       0.984185  0.510067   0.746752    0.683006
# 8   0.016534    6.959799       0.952007  0.289941   0.856318    0.584212
# 9   0.016487    4.142134       0.951683  0.298477   0.758579    0.549524
# 10  0.016528    4.150058       0.954083  0.307853   0.759039    0.555182
# 11  0.016347    3.737946       0.944344  0.275539   0.732473    0.525905
# 12  0.015837    5.450613       0.954033  0.293626   0.816534    0.569694
# 13  0.015706    3.325239       0.949286  0.286735   0.699270    0.519373
# 14  0.014747    3.601323       0.987158  0.507014   0.722324    0.676899
# 15  0.013726    7.151222       0.948847  0.242786   0.860164    0.560197
# 16  0.013787    5.572187       0.953836  0.265795   0.820537    0.555519
# 17  0.013755    5.561549       0.951617  0.257384   0.820194    0.550823
# 18  0.014085    3.432732       0.977178  0.402640   0.708687    0.598039
# 19  0.012483    3.178664       0.950483  0.251986   0.685402    0.491379
# 20  0.012144    3.397153       0.985435  0.451193   0.705636    0.632026
# 21  0.010945    3.835574       0.990617  0.510989   0.739283    0.682000
# 22  0.009913    4.287515       0.974247  0.312614   0.766765    0.558910
